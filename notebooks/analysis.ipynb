# %% [markdown]
# # Social Media Sentiment Analysis
#
# This notebook provides an exploratory analysis of the social media sentiment dataset.

# %%
import pandas as pd

df = pd.read_csv('../data/social_media_data.csv')
df.head()
